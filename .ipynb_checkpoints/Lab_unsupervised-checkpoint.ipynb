# %% [markdown]
# ## GNOD Project - Unsupervised Learning

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
string.split('\n')
# Out:
# ['cid:7f1ce368e29f4f96b7945f7a54f1c168',
#  'csecret:4eaacaf660c747769b3fbb8ab73f07cc']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
secrets_dict
# Out:
# {'cid': '7f1ce368e29f4f96b7945f7a54f1c168',
#  'csecret': '4eaacaf660c747769b3fbb8ab73f07cc'}

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %% [markdown]
# ## Getting the playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "0BUNSGihi2mrhQu3fPcVim")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0BUNSGihi2mrhQu3fPcVim/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2013-05-28T17:17:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0czJqnJDu3vWrLHmsbLunu'},
#        'href': 'https://api.spotify.com/v1/artists/0czJqnJDu3vWrLHmsbLunu',
#        'id': '0czJqnJDu3vWrLHmsbLunu',
#        'name': 'The Muppets',
#        'type': 'artist',
#        'uri': 'spotify:artist:0czJqnJDu3vWrLHmsbLunu'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0mahHDhPnuYMbo3sXOEW50'},
#      'href': 'https://api.spotify.com/v1/albums/0mahHDhPnuYMbo3sXOEW50',
#      'id': '0mahHDhPnuYMbo3sXOEW50',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27349975a26b5562064db3a552b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0249975a26b5562064db3a552b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485149975a26b5562064db3a552b',
#        'width': 64}],
#      'name': 'The Muppets (Original Motion Picture Soundtrack)',
#      'release_date': '2011-11-21',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:0mahHDhPnuYMbo3sXOEW50'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0czJqnJDu3vWrLHmsbLunu'},
#       'href': 'https://api.spotify.com/v1/artists/0czJqnJDu3vWrLHmsbLunu',
#       'id': '0czJqnJDu3vWrLHmsbLunu',
#       'name': 'The Muppets',
#       'type': 'artist',
#       'uri': 'spotify:artist:0czJqnJDu3vWrLHmsbLunu'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 188933,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWD11158966'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1SJ4ycWow4yz6z4oFz8NAG'},
#     'href': 'https://api.spotify.com/v1/tracks/1SJ4ycWow4yz6z4oFz8NAG',
#     'id': '1SJ4ycWow4yz6z4oFz8NAG',
#     'is_local': False,
#     'name': 'Rainbow Connection',
#     'popularity': 54,
#     'preview_url': None,
#     'track': True,
#     'track_number': 24,
#     'type': 'track',
#     'uri': 'spotify:track:1SJ4ycWow4yz6z4oFz8NAG'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-12-29T14:20:20Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ogvuDRerGhZfSf7TtzHlr'},
#        'href': 'https://api.spotify.com/v1/artists/4ogvuDRerGhZfSf7TtzHlr',
#        'id': '4ogvuDRerGhZfSf7TtzHlr',
#        'name': "Israel Kamakawiwo'ole",
#        'type': 'artist',
#        'uri': 'spotify:artist:4ogvuDRerGhZfSf7TtzHlr'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0pquf1NcG9FdiypBPwICu9'},
#      'href': 'https://api.spotify.com/v1/albums/0pquf1NcG9FdiypBPwICu9',
#      'id': '0pquf1NcG9FdiypBPwICu9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d358679de4783983510aa57d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d358679de4783983510aa57d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d358679de4783983510aa57d',
#        'width': 64}],
#      'name': 'Facing Future',
#      'release_date': '1993-11-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:0pquf1NcG9FdiypBPwICu9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ogvuDRerGhZfSf7TtzHlr'},
#       'href': 'https://api.spotify.com/v1/artists/4ogvuDRerGhZfSf7TtzHlr',
#       'id': '4ogvuDRerGhZfSf7TtzHlr',
#       'name': "Israel Kamakawiwo'ole",
#       'type': 'artist',
#       'uri': 'spotify:artist:4ogvuDRerGhZfSf7TtzHlr'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 308026,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMAC9300084'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/25U7raB3ZSszayTYClh4hF'},
#     'href': 'https://api.spotify.com/v1/tracks/25U7raB3ZSszayTYClh4hF',
#     'id': '25U7raB3ZSszayTYClh4hF',
#     'is_local': False,
#     'name': 'Somewhere Over The Rainbow_What A Wonderful World',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2330e66190571dd4bd48ee0eba2f9fa772ea9498?cid=7f1ce368e29f4f96b7945f7a54f1c168',
#     'track': True,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:25U7raB3ZSszayTYClh4hF'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-12-29T14:23:43Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dxF7y4hlGFazdArMsxbEx'},
#        'href': 'https://api.spotify.com/v1/artists/7dxF7y4hlGFazdArMsxbEx',
#        'id': '7dxF7y4hlGFazdArMsxbEx',
#        'name': 'Joey Ramone',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dxF7y4hlGFazdArMsxbEx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4QkB5FT0hN3KWQeeF5Bih5'},
#      'href': 'https://api.spotify.com/v1/albums/4QkB5FT0hN3KWQeeF5Bih5',
#      'id': '4QkB5FT0hN3KWQeeF5Bih5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739782813121bd9927ae3336de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029782813121bd9927ae3336de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519782813121bd9927ae3336de',
#        'width': 64}],
#      'name': "Don't Worry About Me",
#      'release_date': '2002-02-19',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4QkB5FT0hN3KWQeeF5Bih5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dxF7y4hlGFazdArMsxbEx'},
#       'href': 'https://api.spotify.com/v1/artists/7dxF7y4hlGFazdArMsxbEx',
#       'id': '7dxF7y4hlGFazdArMsxbEx',
#       'name': 'Joey Ramone',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dxF7y4hlGFazdArMsxbEx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 143360,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAJE0200531'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/04cdEVbQPb8BJb7593e5fO'},
#     'href': 'https://api.spotify.com/v1/tracks/04cdEVbQPb8BJb7593e5fO',
#     'id': '04cdEVbQPb8BJb7593e5fO',
#     'is_local': False,
#     'name': 'What a Wonderful World',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2caee18dd45efd86fc936f5fe521091029e51e7c?cid=7f1ce368e29f4f96b7945f7a54f1c168',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:04cdEVbQPb8BJb7593e5fO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2013-05-28T17:29:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TwepUY7feaTuipStcyzLZ'},
#        'href': 'https://api.spotify.com/v1/artists/2TwepUY7feaTuipStcyzLZ',
#        'id': '2TwepUY7feaTuipStcyzLZ',
#        'name': 'Asaf Avidan & the Mojos',
#        'type': 'artist',
#        'uri': 'spotify:artist:2TwepUY7feaTuipStcyzLZ'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4lgU3GEl4DTGAEEYW22ObO'},
#      'href': 'https://api.spotify.com/v1/albums/4lgU3GEl4DTGAEEYW22ObO',
#      'id': '4lgU3GEl4DTGAEEYW22ObO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dc4b6b7a94a22e4d09dbd287',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dc4b6b7a94a22e4d09dbd287',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dc4b6b7a94a22e4d09dbd287',
#        'width': 64}],
#      'name': 'One Day / Reckoning Song (Wankelmut Remix)',
#      'release_date': '2012-08-24',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:4lgU3GEl4DTGAEEYW22ObO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TwepUY7feaTuipStcyzLZ'},
#       'href': 'https://api.spotify.com/v1/artists/2TwepUY7feaTuipStcyzLZ',
#       'id': '2TwepUY7feaTuipStcyzLZ',
#       'name': 'Asaf Avidan & the Mojos',
#       'type': 'artist',
#       'uri': 'spotify:artist:2TwepUY7feaTuipStcyzLZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/01e2lCvLZ4fLUIRy68nptH'},
#       'href': 'https://api.spotify.com/v1/artists/01e2lCvLZ4fLUIRy68nptH',
#       'id': '01e2lCvLZ4fLUIRy68nptH',
#       'name': 'Wankelmut',
#       'type': 'artist',
#       'uri': 'spotify:artist:01e2lCvLZ4fLUIRy68nptH'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 212360,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEQ321200132'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5HSkycOEtb9iQ7cg1Oyqmu'},
#     'href': 'https://api.spotify.com/v1/tracks/5HSkycOEtb9iQ7cg1Oyqmu',
#     'id': '5HSkycOEtb9iQ7cg1Oyqmu',
#     'is_local': False,
#     'name': 'One Day / Reckoning Song (Wankelmut Remix) [Radio Edit]',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5HSkycOEtb9iQ7cg1Oyqmu'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-12-29T14:23:29Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19eLuQmk9aCobbVDHc6eek'},
#        'href': 'https://api.spotify.com/v1/artists/19eLuQmk9aCobbVDHc6eek',
#        'id': '19eLuQmk9aCobbVDHc6eek',
#        'name': 'Louis Armstrong',
#        'type': 'artist',
#        'uri': 'spotify:artist:19eLuQmk9aCobbVDHc6eek'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/16niuq7vcf4QvnnrJO7yFc'},
#      'href': 'https://api.spotify.com/v1/albums/16niuq7vcf4QvnnrJO7yFc',
#      'id': '16niuq7vcf4QvnnrJO7yFc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738496ba38d3eaaa0a076be39e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028496ba38d3eaaa0a076be39e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518496ba38d3eaaa0a076be39e',
#        'width': 64}],
#      'name': 'All Time Greatest Hits',
#      'release_date': '1994-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:16niuq7vcf4QvnnrJO7yFc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19eLuQmk9aCobbVDHc6eek'},
#       'href': 'https://api.spotify.com/v1/artists/19eLuQmk9aCobbVDHc6eek',
#       'id': '19eLuQmk9aCobbVDHc6eek',
#       'name': 'Louis Armstrong',
#       'type': 'artist',
#       'uri': 'spotify:artist:19eLuQmk9aCobbVDHc6eek'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 140333,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC16758823'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2pp3RfqX5cb1BAnmNi4Nej'},
#     'href': 'https://api.spotify.com/v1/tracks/2pp3RfqX5cb1BAnmNi4Nej',
#     'id': '2pp3RfqX5cb1BAnmNi4Nej',
#     'is_local': False,
#     'name': 'What A Wonderful World - Single Version',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2pp3RfqX5cb1BAnmNi4Nej'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2013-05-28T17:33:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#        'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#        'id': '7oPftvlwr6VrsViSDV7fJY',
#        'name': 'Green Day',
#        'type': 'artist',
#        'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5dN7F9DV0Qg1XRdIgW8rke'},
#      'href': 'https://api.spotify.com/v1/albums/5dN7F9DV0Qg1XRdIgW8rke',
#      'id': '5dN7F9DV0Qg1XRdIgW8rke',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27308a1b1e0674086d3f1995e1b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0208a1b1e0674086d3f1995e1b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485108a1b1e0674086d3f1995e1b',
#        'width': 64}],
#      'name': 'American Idiot',
#      'release_date': '2004-09-21',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:5dN7F9DV0Qg1XRdIgW8rke'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#       'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#       'id': '7oPftvlwr6VrsViSDV7fJY',
#       'name': 'Green Day',
#       'type': 'artist',
#       'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 558520,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRE10400993'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4wH29TM74O3788Kn1KzWuY'},
#     'href': 'https://api.spotify.com/v1/tracks/4wH29TM74O3788Kn1KzWuY',
#     'id': '4wH29TM74O3788Kn1KzWuY',
#     'is_local': False,
#     'name': 'Homecoming',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5be5e13ed070fd1cf1a374983c749dfbc0a79299?cid=7f1ce368e29f4f96b7945f7a54f1c168',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:4wH29TM74O3788Kn1KzWuY'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2013-05-28T17:33:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#        'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#        'id': '7oPftvlwr6VrsViSDV7fJY',
#        'name': 'Green Day',
#        'type': 'artist',
#        'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5dN7F9DV0Qg1XRdIgW8rke'},
#      'href': 'https://api.spotify.com/v1/albums/5dN7F9DV0Qg1XRdIgW8rke',
#      'id': '5dN7F9DV0Qg1XRdIgW8rke',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27308a1b1e0674086d3f1995e1b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0208a1b1e0674086d3f1995e1b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485108a1b1e0674086d3f1995e1b',
#        'width': 64}],
#      'name': 'American Idiot',
#      'release_date': '2004-09-21',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:5dN7F9DV0Qg1XRdIgW8rke'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#       'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#       'id': '7oPftvlwr6VrsViSDV7fJY',
#       'name': 'Green Day',
#       'type': 'artist',
#       'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 285653,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRE10400992'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ZffCQKLFLUvYM59XKLbVm'},
#     'href': 'https://api.spotify.com/v1/tracks/3ZffCQKLFLUvYM59XKLbVm',
#     'id': '3ZffCQKLFLUvYM59XKLbVm',
#     'is_local': False,
#     'name': 'Wake Me up When September Ends',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a83eedd6b982d4afdc2ceaeb458f471118ad78aa?cid=7f1ce368e29f4f96b7945f7a54f1c168',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:3ZffCQKLFLUvYM59XKLbVm'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2013-05-28T17:33:24Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#        'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#        'id': '7oPftvlwr6VrsViSDV7fJY',
#        'name': 'Green Day',
#        'type': 'artist',
#        'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5dN7F9DV0Qg1XRdIgW8rke'},
#      'href': 'https://api.spotify.com/v1/albums/5dN7F9DV0Qg1XRdIgW8rke',
#      'id': '5dN7F9DV0Qg1XRdIgW8rke',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27308a1b1e0674086d3f1995e1b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0208a1b1e0674086d3f1995e1b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485108a1b1e0674086d3f1995e1b',
#        'width': 64}],
#      'name': 'American Idiot',
#      'release_date': '2004-09-21',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:5dN7F9DV0Qg1XRdIgW8rke'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7oPftvlwr6VrsViSDV7fJY'},
#       'href': 'https://api.spotify.com/v1/artists/7oPftvlwr6VrsViSDV7fJY',
#       'id': '7oPftvlwr6VrsViSDV7fJY',
#       'name': 'Green Day',
#       'type': 'artist',
#       'uri': 'spotify:artist:7oPftvlwr6VrsViSDV7fJY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 548253,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRE10400983'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/58KPPL1AdLHMvR2O2PZejr'},
#     'href': 'https://api.spotify.com/v1/tracks/58KPPL1AdLHMvR2O2PZejr',
#     'id': '58KPPL1AdLHMvR2O2PZejr',
#     'is_local': False,
#     'name': 'Jesus of Suburbia',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ec083b4edfdd1a4cbfb642b231d797e67ceaf69f?cid=7f1ce368e29f4f96b7945f7a54f1c168',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:58KPPL1AdLHMvR2O2PZejr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2013-05-28T18:10:58Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
# ...
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7t0rwkOPGlDPEhaOcVtOt9'},
#        'href': 'https://api.spotify.com/v1/artists/7t0rwkOPGlDPEhaOcVtOt9',
#        'id': '7t0rwkOPGlDPEhaOcVtOt9',
#        'name': 'The Cranberries',
#        'type': 'artist',
#        'uri': 'spotify:artist:7t0rwkOPGlDPEhaOcVtOt9'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5GugLrmYMl5VRoe2zNgLGp'},
#      'href': 'https://api.spotify.com/v1/albums/5GugLrmYMl5VRoe2zNgLGp',
#      'id': '5GugLrmYMl5VRoe2zNgLGp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e2213d84fabb15100c425198',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e2213d84fabb15100c425198',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e2213d84fabb15100c425198',
#        'width': 64}],
#      'name': 'No Need To Argue',
#      'release_date': '1994-10-03',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5GugLrmYMl5VRoe2zNgLGp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7t0rwkOPGlDPEhaOcVtOt9'},
#       'href': 'https://api.spotify.com/v1/artists/7t0rwkOPGlDPEhaOcVtOt9',
#       'id': '7t0rwkOPGlDPEhaOcVtOt9',
#       'name': 'The Cranberries',
#       'type': 'artist',
#       'uri': 'spotify:artist:7t0rwkOPGlDPEhaOcVtOt9'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 306426,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR29400443'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2IZZqH4K02UIYg5EohpNHF'},
#     'href': 'https://api.spotify.com/v1/tracks/2IZZqH4K02UIYg5EohpNHF',
#     'id': '2IZZqH4K02UIYg5EohpNHF',
#     'is_local': False,
#     'name': 'Zombie',
#     'popularity': 21,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2IZZqH4K02UIYg5EohpNHF'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-30T00:37:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MVyzYMgTwdP7Z49wAZHx0'},
#        'href': 'https://api.spotify.com/v1/artists/4MVyzYMgTwdP7Z49wAZHx0',
#        'id': '4MVyzYMgTwdP7Z49wAZHx0',
#        'name': 'Lynyrd Skynyrd',
#        'type': 'artist',
#        'uri': 'spotify:artist:4MVyzYMgTwdP7Z49wAZHx0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6DExt1eX4lflLacVjHHbOs'},
#      'href': 'https://api.spotify.com/v1/albums/6DExt1eX4lflLacVjHHbOs',
#      'id': '6DExt1eX4lflLacVjHHbOs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273128450651c9f0442780d8eb8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02128450651c9f0442780d8eb8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851128450651c9f0442780d8eb8',
#        'width': 64}],
#      'name': "Pronounced' Leh-'Nerd 'Skin-'Nerd",
#      'release_date': '1973-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:6DExt1eX4lflLacVjHHbOs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MVyzYMgTwdP7Z49wAZHx0'},
#       'href': 'https://api.spotify.com/v1/artists/4MVyzYMgTwdP7Z49wAZHx0',
#       'id': '4MVyzYMgTwdP7Z49wAZHx0',
#       'name': 'Lynyrd Skynyrd',
#       'type': 'artist',
#       'uri': 'spotify:artist:4MVyzYMgTwdP7Z49wAZHx0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 547106,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC17301722'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5EWPGh7jbTNO2wakv8LjUI'},
#     'href': 'https://api.spotify.com/v1/tracks/5EWPGh7jbTNO2wakv8LjUI',
#     'id': '5EWPGh7jbTNO2wakv8LjUI',
#     'is_local': False,
#     'name': 'Free Bird',
#     'popularity': 75,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:5EWPGh7jbTNO2wakv8LjUI'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-31T21:18:02Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/darkspy72'},
#     'href': 'https://api.spotify.com/v1/users/darkspy72',
#     'id': 'darkspy72',
#     'type': 'user',
#     'uri': 'spotify:user:darkspy72'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5y2Xq6xcjJb2jVM54GHK3t'},
#        'href': 'https://api.spotify.com/v1/artists/5y2Xq6xcjJb2jVM54GHK3t',
#        'id': '5y2Xq6xcjJb2jVM54GHK3t',
#        'name': 'John Legend',
#        'type': 'artist',
#        'uri': 'spotify:artist:5y2Xq6xcjJb2jVM54GHK3t'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4OTAx9un4e6NfoHuVRiOrC'},
#      'href': 'https://api.spotify.com/v1/albums/4OTAx9un4e6NfoHuVRiOrC',
#      'id': '4OTAx9un4e6NfoHuVRiOrC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27394c9217a398f5174757c0c78',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0294c9217a398f5174757c0c78',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485194c9217a398f5174757c0c78',
#        'width': 64}],
#      'name': 'Love In The Future (Expanded Edition)',
#      'release_date': '2013-08-30',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:4OTAx9un4e6NfoHuVRiOrC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5y2Xq6xcjJb2jVM54GHK3t'},
#       'href': 'https://api.spotify.com/v1/artists/5y2Xq6xcjJb2jVM54GHK3t',
#       'id': '5y2Xq6xcjJb2jVM54GHK3t',
#       'name': 'John Legend',
#       'type': 'artist',
#       'uri': 'spotify:artist:5y2Xq6xcjJb2jVM54GHK3t'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 269560,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11303954'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3U4isOIWM3VvDubwSI3y7a'},
#     'href': 'https://api.spotify.com/v1/tracks/3U4isOIWM3VvDubwSI3y7a',
#     'id': '3U4isOIWM3VvDubwSI3y7a',
#     'is_local': False,
#     'name': 'All of Me',
#     'popularity': 86,
#     'preview_url': 'https://p.scdn.co/mp3-preview/488c53471e56ff9f629652691444438951e880bb?cid=7f1ce368e29f4f96b7945f7a54f1c168',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3U4isOIWM3VvDubwSI3y7a'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/0BUNSGihi2mrhQu3fPcVim/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 815}

# %%
len(playlist["items"])
# Out:
# 100

# %%
playlist['next']
# Out:
# 'https://api.spotify.com/v1/playlists/0BUNSGihi2mrhQu3fPcVim/tracks?offset=100&limit=100&additional_types=track'

# %% [markdown]
# ## Getting songs and song information

# %%
from random import randint
from time import sleep
# 1) This gets all tracks from the playlist

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
all_tracks = get_playlist_tracks("0BUNSGihi2mrhQu3fPcVim")
len(all_tracks)
# Out:
# 815

# %%
def all_artists(all_tracks):
    artist = [all_tracks[i]['track']['artists'][0]['name'] for i in range(len(all_tracks))]
    return artist
all_artists = all_artists(all_tracks)

# %%
df_all_artists = pd.DataFrame(all_artists, columns=['artist'])
df_all_artists.shape
# Out:
# (815, 1)

# %%
def all_track_names(all_tracks):
    names = [all_tracks[i]['track']['name'] for i in range(len(all_tracks))]      #tracks
    return names
all_track_names = all_track_names(all_tracks)
df_all_track_names = pd.DataFrame(all_track_names, columns=['name'])          #tracks data frame
df_all_track_names.shape
# Out:
# (815, 1)

# %%
def uris(all_tracks):
    uris = [all_tracks[i]['track']['uri'] for i in range(len(all_tracks))]
    return uris
all_uris = uris(all_tracks)
df_all_uris = pd.DataFrame(all_uris, columns=['uris'])

# %%
songs = pd.concat([df_all_track_names, df_all_artists, df_all_uris], axis=1 )

# %%
features = [sp.audio_features(i) for i in (all_uris)]

# %%
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]


features_new = flatten(features)
features_new[0]
# Out:
# {'danceability': 0.526,
#  'energy': 0.413,
#  'key': 9,
#  'loudness': -7.674,
#  'mode': 1,
#  'speechiness': 0.0278,
#  'acousticness': 0.428,
#  'instrumentalness': 0,
#  'liveness': 0.126,
#  'valence': 0.211,
#  'tempo': 115.936,
#  'type': 'audio_features',
#  'id': '1SJ4ycWow4yz6z4oFz8NAG',
#  'uri': 'spotify:track:1SJ4ycWow4yz6z4oFz8NAG',
#  'track_href': 'https://api.spotify.com/v1/tracks/1SJ4ycWow4yz6z4oFz8NAG',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SJ4ycWow4yz6z4oFz8NAG',
#  'duration_ms': 188933,
#  'time_signature': 3}

# %%
danceability = [features_new[i]['danceability'] for i in range(len(features_new))]
energy = [features_new[i]['energy'] for i in range(len(features_new))]
key = [features_new[i]['key'] for i in range(len(features_new))]
loudness = [features_new[i]['loudness'] for i in range(len(features_new))]
mode = [features_new[i]['mode'] for i in range(len(features_new))]
speechiness = [features_new[i]['speechiness'] for i in range(len(features_new))]
acousticness = [features_new[i]['acousticness'] for i in range(len(features_new))]
instrumentalness = [features_new[i]['instrumentalness'] for i in range(len(features_new))]
liveness = [features_new[i]['liveness'] for i in range(len(features_new))]
valence = [features_new[i]['valence'] for i in range(len(features_new))]
tempo = [features_new[i]['tempo'] for i in range(len(features_new))]

# %%
# Create a Dataframe from all features
df_all_features = pd.DataFrame.from_dict({'danceability':danceability, 'energy':energy, 'key':key, 
                                         'loudness':loudness, 'mode':mode, 'speechiness':speechiness, 
                                         'acousticness':acousticness, 'instrumentalness':instrumentalness, 
                                         'liveness':liveness, 'valence':valence, 'tempo':tempo})

# %%
df_all_features.to_csv('df_all_features.csv')

# %%
all_tracks_1 = pd.concat([df_all_track_names, df_all_artists, df_all_uris, df_all_features], axis=1 )

# %% [markdown]
# ## Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D

# %%
# Model building for Clustering. Creating scaler
x_transformer = StandardScaler().fit(df_all_features)

# %%
x_prep = x_transformer.transform(df_all_features)

# %%
print(scaler.shape)
# Out:
# (813, 11)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(x_prep)
# Out:
# KMeans(n_clusters=3, random_state=1234)

# %%
kmeans.inertia_
# Out:
# 6787.997962155754

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(x_prep)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     42
# 1    488
# 2    285
# dtype: int64

# %%
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(x_prep)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'r*-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
#kmeans = KMeans(n_clusters=5, random_state=1234)
#kmeans.fit(x_prep)
#clusters = kmeans.predict(x_prep)
#pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     42
# 1    299
# 2    184
# 3    106
# 4    184
# dtype: int64

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(x_prep)
    silhouette.append(silhouette_score(x_prep, kmeans.predict(x_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-') # the "bx-" means: blue line with an x at each point
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn import cluster, datasets
agglomerative = cluster.AgglomerativeClustering(n_clusters=3,linkage='ward')
pred = agglomerative.fit_predict(x_prep)
plt.figure(figsize=(10, 10))
plt.scatter(x_prep[:, 0], x_prep[:, 1], c=pred,alpha=0.5)
plt.show()

# %%
all_tracks_final = pd.concat([all_tracks_1, pd.Series(clusters)], axis=1 )

# %%
all_tracks_final[0].unique()
# Out:
# array([2, 1, 0])

# %%
all_tracks_final.to_csv('all_tracks_final.csv')

# %%
all_tracks_final = all_tracks_final.rename({0:'cluster'}, axis=1)

# %%
all_tracks_final
